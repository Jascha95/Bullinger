# %%
# ET.fromstring(String) --> element 
# ET.tostring(Element) --> string
# ET.parse(File) --> string
# to get the attribute call get method on the element

#language = s.get('lang')
#if language == 'de'

# %%
import os
import xml.etree.ElementTree as ET
import re

# list with the words and their footnotes:
references_list=[]
filtered_dictionary = {}


# the directory where the files are located 
directory_path = r"C:\Users\Anna Bondar\Desktop\projet web applications\Bullinger_Letter_Examples" 

# iterate through directory and subdirectories
for root, dirs, files in os.walk(directory_path):
    for filename in files:
        # the full file path
        full_path = os.path.join(root, filename)
        # if the file if in the directory
        if os.path.isfile(full_path):
            # the XML file parsing
            file_tree = ET.parse(full_path)
            root_element = file_tree.getroot()
            #itterating over the sentences
            #print (full_path)
            for sentence in root_element.findall('.//s'):
                #if the language is German, we are considerign those sentences, otherwise--> ignore those:
                if sentence.attrib.get('lang') == 'de':
                    
                    # itterate over the child elements of the sentence
                    for i, child in enumerate(sentence):
                        #if the fl child tag is encountered:
                        if child.tag == 'fl' and child.text.isdigit():
                            # determine the preceding text if this is the first child tag in the sentence
                            if i == 0:
                                preceding_text = sentence.text.strip() if sentence.text else ""
                            
                            # if this is not the first child tag in the sentence, the word before fl tag will be the 
                            # last word in the text of the preceding tag
                            else:
                                preceding_text = sentence[i - 1].tail.strip() if sentence[i - 1].tail else ""

                            # the text is split and the last word is taken
                            words = preceding_text.split()
                            if words:
                                word_before_fl = words[-1]
                                #print("Word before <fl>:", word_before_fl)

                            # Extract the number inside <fl>
                            number = child.text

                            # the matching reference gets stored in a table
                            for reference in root_element.findall('.//fn'):
                                if reference.attrib.get('ref') == number and reference.text != None:
                                    references_list.append((word_before_fl, reference.text, len(reference.text)))

#  filtered out the elements where the length of the references is >45:

filtered_references_list = [element for element in references_list if len(element[1]) <= 45]
print (len(filtered_references_list))

# filtered out the references which have many numbers:
filtered_references_list_2 = [element for element in filtered_references_list if not re.search("[0-9]", element[1])]

print (len(filtered_references_list_2))


for element in filtered_references_list_2:
    if element[0] not in filtered_dictionary:
        filtered_dictionary[element[0]] = [element[1]]
#     elif filtered_dictionary[element[0]] == [element[1]]:
#         pass
    else:
        filtered_dictionary[element[0]].append(element[1])

print (len(filtered_dictionary), filtered_dictionary )
                                    
                                
            
            
            # if placeName/ personName in reference -- irrelevant
# Out:
# 2192
# 2076
# 1512 {'ist': ['verbreitet worden ist. - So soll auch ', 'fest der Absicht ist.', 'daß es zutrifft.'], 'nun': ['nur.', '- nur.', 'nur.', 'nur.'], 'als': ['wie.', 'derart.', 'wie.', 'die brieff als: alle Briefe.', 'wie auch.', 'wie.', 'wie.', 'alles.', 'wie auch.', 'wie.'], 'gehorsammi': ['Gehorsam leiste.'], 'umgand': ['sich befassen.'], 'hulden': ['sich dazu verpflichten.'], 'schryben': ['Oben '], 'erheben': ['zu erreichen.', 'erreichen.', 'unternehmen; s. '], 'mencklich': ['jedermann.'], 'fertigen': ['zuwege bringen.', 'abfertigen.'], 'schlecht': ['einfach.', 'tut.'], 'gang': ['sich befasse.'], 'schühen': ['immer eine Abneigung.'], 'weist': ['weiß.'], 'verston': ['sehe ich keinen Anlaß zur Annahme.'], 'ützid': ['etwas.'], 'beschiessen': ['helfen.'], 'gehertzigist': ['am mutigsten.'], 'erhöüschen': ['erfordern.'], 'zuosetzen': ['Beistand leisten.'], 'bericht': ['davon unterrichtet.', 'nicht unterrichtet ist.', 'zuverlässig informiert.', 'Vertrag; s. ', 'Information, Nachricht, Bescheid.'], 'begäben': ['sich auf etwas festlegen.'], 'tagen': ['Tagungen abhalten.'], 'ersten': ['unerwartet und erstmals.'], 'ersuche': ['behellige.'], 'gleiche': ['ebenfalls.'], 'zu': ['nach.'], 'fürkommen': ['und weil mir überraschend ein Briefbote nach '], 'aber': ['auch.', 'und aber: jedoch.', 'wieder.'], 'zustand': ['Wohlergehen.'], 'frist': ['erhalte, bewahre.'], 'langwyriger': ['dauerhafter.'], 'durchächtung': ['Verfolgung.'], 'alls': ['immer.', 'so.', 'wie.', 'alles.', 'so.', 'so.', 'so.'], 'stecken': ['Vgl. oben '], 'kaat': ['Schmutz.'], 'usschlachen': ['[zum Nachteil] ausgehen.'], 'lut': ['etwa im Sinne von: entschlossene Leute.'], 'hindersich': ['in den Rückstand.'], 'sige': ['sei.'], 'apprellens': ['Nicht erhalten.'], 'erschlich': ['erstlich.'], 'zitung': ['neuen Nachrichten.', 'Nachricht.'], 'alß': ['wie.', 'all(es).'], 'aptz': ['gewesen.'], 'funden': ['angetroffen.'], 'anstand': ['das Stillstandsabkommen. -Zum "'], 'ansähens': ['Übereinkunft.'], 'verschinung': ['Ablauf.'], 'Rägenspurg': ['Von '], 'verglichen': ['einigen.'], 'beschähen': ['weitere Schritte erwogen werden.'], 'nächstenn': ['auf dem kürzesten Weg.'], 'sigind': ['Die Herzöge von Braunschweig-Lüneburg, '], 'eigentlichs': ['noch nichts Sicheres.', 'Genaues; s. '], 'forigem': ['Das letzte erhaltene Schreiben '], 'wol': ['sehr gut.', 'Wie wol: Genauso wie.', 'wohl aber.'], 'Fürer': ['Ferner.'], 'forgemeltenn': ['oben erwähnten.'], 'kundtschafft': ['Zeugnis.'], 'mag': ['kann.', 'gespurren mag: spüren konnte.'], 'halb': ['im Familiären.'], 'ob': ['wenn.', 'bis; s. ', 'sobald.', 'so.', 'falls.'], 'wil': ['Muße.'], 'bropst': ['Gemeint ist wohl '], 'kind': ['Siehe oben ', 'Unbekannt.', 'Tochter Agnes und Sohn Johannes.', 'Zu deren Namen s. ', 'Unbekannt.'], 'fernn': ['immerdar.'], 'bu[tzen]werck': ['hoffärtigen Mummenschanz (vgl. auch '], 'Denn': ['Dann.'], 'wi]derwertigen': ['Feinde.'], 'Ryns': ['jenseits des '], 'nahin': ['nachher.'], 'Schlächts': ['Kurzum.'], 'heyter': ['klar.'], 'gerüwen': ['er bereut es beinahe.'], 'siechtagen': ['Krankheit.'], 'denn': ['bald ... bald.'], 'ettwan': ['manchmal.'], 'versehen': ['nur unzureichend betreut.', 'dafür sorgen; '], 'onvermögens': ['wegen seiner Kränklichkeit.'], 'blodt': ['schwach.'], 'erkennt': ['beurteilt.'], 'handen': ['vorgenommen.'], 'vollendung': ['Ausführung.'], 'stätten': ['ständigen.'], 'herumb': ['deshalb.'], 'dienstlich': ['dienstbeflissen, ergeben.', 'dienstfertig.'], 'anzehalten': ['zu bitten, zu drängen.'], 'begabt': ['dotiert.'], 'achten': ['erachten.', 'alls zü achten: wie zu vermuten (ist).'], 'besonder': ['gemeinsam und jedem einzelnen.'], 'zuverdienen': ['zu entgelten.'], 'bittschett': ['Petschaft.'], 'merckzeichen': ['Kennzeichen.'], 'chronicken': ['Zur Zusammenarbeit ', 'Wohl '], 'abkent': ['seines Pfarramtes in '], 'murmur': ['Gemurre, Unwillen.'], 'glimpff': ['Nachdruck.'], 'anstoß': ['Grenze.'], 'befleckt': ['Vgl. oben '], 'kybigem': ['eigensinnigem, zänkischem.'], 'eygnenn': ['Untertan.'], 'benyegen': ['gebe ich  ...
