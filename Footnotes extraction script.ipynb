# %%
# ET.fromstring(String) --> element 
# ET.tostring(Element) --> string
# ET.parse(File) --> string
# to get the attribute call get method on the element

#language = s.get('lang')
#if language == 'de'

# %%
import os
import xml.etree.ElementTree as ET
import re

# list with the words and their footnotes:
references_list=[]
filtered_dictionary = {}


# the directory where the files are located 
directory_path = r"/Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples" 

# iterate through directory and subdirectories
for root, dirs, files in os.walk(directory_path):
    for filename in files:
        # the full file path
        full_path = os.path.join(root, filename)
        # if the file if in the directory
        if os.path.isfile(full_path): #file_tree = ET.parse(full_path)
            # the XML file parsing
            
            file_tree = ET.parse(full_path) #file_tree = ET.parse(full_path) error
            root_element = file_tree.getroot()
            #itterating over the sentences
            print (full_path)
            for sentence in root_element.findall('.//s'):
                #if the language is German, we are considerign those sentences, otherwise--> ignore those:
                if sentence.attrib.get('lang') == 'de':
                    
                    # itterate over the child elements of the sentence
                    for i, child in enumerate(sentence):
                        #if the fl child tag is encountered:
                        if child.tag == 'fl' and child.text.isdigit():
                            # determine the preceding text if this is the first child tag in the sentence
                            if i == 0:
                                preceding_text = sentence.text.strip() if sentence.text else ""
                            
                            # if this is not the first child tag in the sentence, the word before fl tag will be the 
                            # last word in the text of the preceding tag
                            else:
                                preceding_text = sentence[i - 1].tail.strip() if sentence[i - 1].tail else ""

                            # the text is split and the last word is taken
                            words = preceding_text.split()
                            if words:
                                word_before_fl = words[-1]
                                #print("Word before <fl>:", word_before_fl)

                            # Extract the number inside <fl>
                            number = child.text

                            # the matching reference gets stored in a table
                            for reference in root_element.findall('.//fn'):
                                if reference.attrib.get('ref') == number and reference.text != None:
                                    references_list.append((word_before_fl, reference.text, len(reference.text)))

#  filtered out the elements where the length of the references is >45:

filtered_references_list = [element for element in references_list if len(element[1]) <= 45]
print (len(filtered_references_list))

# filtered out the references which have many numbers:
filtered_references_list_2 = [element for element in filtered_references_list if not re.search("[0-9]", element[1])]

print (len(filtered_references_list_2))


for element in filtered_references_list_2:
    if element[0] not in filtered_dictionary:
        filtered_dictionary[element[0]] = [element[1]]
#     elif filtered_dictionary[element[0]] == [element[1]]:
#         pass
    else:
        filtered_dictionary[element[0]].append(element[1])

print (len(filtered_dictionary), filtered_dictionary )
                                    
                                
            
            
            # if placeName/ personName in reference -- irrelevant
# Out:
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2761_12810.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1342_11385.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2848_12897.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1227_11270.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1279_11322.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2845_12894.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2807_12856.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2816_12865.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1312_11355.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1286_11329.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1283_11326.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2852_12901.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2832_12881.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2801_12850.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2770_12819.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1236_11279.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2820_12869.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1253_11296.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2840_12889.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1233_11276.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2754_12803.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1256_11299.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/09_1271_11314.xml
# /Users/yasardemirelli/cmd_code/Uni_UZH/WS23:24/Sprachtechnologische_Webapplikationen/Project Bullinger/Bullinger_Letter_Examples/19_2809_12858.xml
# Traceback (most recent call last):
#
#   File ~/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3548 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 22
#     file_tree = ET.parse(full_path)
#
#   File ~/miniconda3/lib/python3.11/xml/etree/ElementTree.py:1218 in parse
#     tree.parse(source, parser)
#
#   File ~/miniconda3/lib/python3.11/xml/etree/ElementTree.py:580 in parse
#     self._root = parser._parse_whole(source)
#
#   File <string>
# ParseError: not well-formed (invalid token): line 1, column 0
